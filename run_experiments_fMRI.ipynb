# %% [markdown]
# # Run experiment on fMRI datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import os

print([np.__version__, pd.__version__])
np.set_printoptions(precision=3, suppress=True)


from src.data_preprocessing import preprocess_data
from src.plotting import plot_heatmap
from src.causal_matrix_evaluation import evaluate_causal_matrices
from src.matrix_utils import read_matrices_from_csv, save_matrices, get_summary_matrix
from src.run_causal_discovery import run_varlingam, run_varlingam_bootstrap, run_pcmci, run_rcv_varlingam, run_rcv_pcmci, run_tcdf
# Out:
# ['1.24.4', '2.0.3']

# %%
def run_experiments(dataset_indices, methods=['varlingam', 'pcmci', 'rcv_varlingam', 'rcv_pcmci', 'tcdf']):
    """
    Run causal discovery experiments on fMRI datasets.
    
    Args:
        dataset_indices: List of dataset indices to process
        methods: List of methods to run
    """
    results = {method: [] for method in methods}
    
    for index in dataset_indices:
        print(f"Processing dataset {index}")
        
        # Load ground truths
        ground_truths_path = f'data/real/fMRI/ground_truths/sim{index}_gt_processed_adj.csv'
        ground_truths = read_matrices_from_csv(ground_truths_path)
        
        if ground_truths is None:
            print(f"Skipping dataset {index} due to missing ground truths")
            continue
            
        # Get summary ground truth matrix
        ground_truth_summary = get_summary_matrix(ground_truths)
        
        for method in methods:
            # Load data
            data = pd.read_csv(f'data/real/fMRI/returns/timeseries{index}.csv')
            columns = data.columns.tolist()
            
            # Remove timestamp column if present
            for time_col in ['Date', 'timestamp']:
                if time_col in columns:
                    data = data.drop([time_col], axis=1)
                    columns.remove(time_col)
            
            data = data.values

            # Preprocess data
            data = preprocess_data(data, columns)

            # Run causal discovery method
            start_time = time.time()
            
            if method == 'varlingam':
                adjacency_matrices = run_varlingam(data)
            elif method == 'varlingam_bootstrap':
                adjacency_matrices = run_varlingam_bootstrap(data)
            elif method == 'pcmci':
                adjacency_matrices = run_pcmci(data, columns)
            elif method == 'rcv_varlingam':
                adjacency_matrices = run_rcv_varlingam(data)
            elif method == 'rcv_pcmci':
                adjacency_matrices = run_rcv_pcmci(data)
            elif method == 'tcdf':
                adjacency_matrices = run_tcdf(data)
            else:
                raise ValueError(f"Unknown method: {method}")
                
            runtime = round(time.time() - start_time, 4)

            # Trim adjacency matrices if needed
            if len(adjacency_matrices) > len(ground_truths):
                adjacency_matrices = adjacency_matrices[:len(ground_truths)]

            # Get summary matrix from method results
            method_summary = get_summary_matrix(adjacency_matrices)

            # Save results
            output_path = f'results/real/fMRI/timeseries{index}/adj_matrices_{method}.csv'
            summary_path = f'results/real/fMRI/timeseries{index}/sum_adj_matrix_{method}.csv'
            os.makedirs(os.path.dirname(output_path), exist_ok=True)
            save_matrices(adjacency_matrices, output_path)
            save_matrices([method_summary], summary_path)

            # Evaluate both full and summary matrices
            full_evaluation = evaluate_causal_matrices(ground_truths, adjacency_matrices)
            summary_evaluation = evaluate_causal_matrices([ground_truth_summary], [method_summary])

            # Store results
            result = {
                'dataset': index,
                'Full_SHD': full_evaluation['shd'],
                'Full_F1': full_evaluation['f1'],
                'Full_F1_sign': full_evaluation['f1_sign'],
                'Full_Frobenius': full_evaluation['fro'],
                'Summary_SHD': summary_evaluation['shd'],
                'Summary_F1': summary_evaluation['f1'],
                'Summary_F1_sign': summary_evaluation['f1_sign'],
                'Summary_Frobenius': summary_evaluation['fro'],
                'runtime': runtime
            }
            results[method].append(result)

    # Save summary results for each method
    for method in methods:
        df_results = pd.DataFrame(results[method])
        
        # Calculate statistics for numeric columns
        numeric_cols = df_results.select_dtypes(include=[np.number]).columns
        numeric_cols = [col for col in numeric_cols if col not in ['dataset']]
        avg_result = df_results[numeric_cols].mean()
        std_result = df_results[numeric_cols].std()

        # Create summary row
        summary = {
            'dataset': 'Overall Average',
            **{col: (f"{avg_result[col]:.4f} ± {std_result[col]:.4f}" 
                    if col != 'runtime' else f"{avg_result[col]:.4f}")
               for col in numeric_cols}
        }
        
        # Add summary to results
        df_results = pd.concat([df_results, pd.DataFrame([summary])], ignore_index=True)
        
        # Save to CSV
        output_path = f'results/real/fMRI/performance_{method}.csv'
        df_results.to_csv(output_path, index=False)

# %%
# Define datasets to process (excluding dataset 4)
dataset_indices = [i for i in range(1, 29) if i != 4]

# Define methods to run
methods_to_run = ['varlingam', 'pcmci', 'rcv_varlingam', 'rcv_pcmci', 'tcdf']

# Run experiments
run_experiments(dataset_indices, methods=methods_to_run)
# Out:
# Processing dataset 1
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 3
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable 0 has 1 link(s):
#         (0 -1): max_pval = 0.00000, |min_val| =  0.447
#
#     Variable 1 has 2 link(s):
#         (1 -1): max_pval = 0.00000, |min_val| =  0.450
#         (3 -2): max_pval = 0.01160, |min_val| =  0.181
#
#     Variable 2 has 1 link(s):
#         (2 -1): max_pval = 0.00000, |min_val| =  0.348
#
#     Variable 3 has 1 link(s):
#         (3 -1): max_pval = 0.00005, |min_val| =  0.287
#
#     Variable 4 has 2 link(s):
#         (4 -1): max_pval = 0.00000, |min_val| =  0.327
#         (4 -2): max_pval = 0.00125, |min_val| =  0.230
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 3
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable 0 has 4 link(s):
#         (0 -1): pval = 0.00000 | val =  0.549
#         (0 -2): pval = 0.00000 | val = -0.348
#         (1  0): pval = 0.00017 | val =  0.269 | unoriented link
#         (4  0): pval = 0.02531 | val =  0.162 | unoriented link
#
#     Variable 1 has 7 link(s):
#         (1 -1): pval = 0.00000 | val =  0.521
#         (0  0): pval = 0.00017 | val =  0.269 | unoriented link
#         (2  0): pval = 0.00053 | val =  0.248 | unoriented link
#         (1 -2): pval = 0.00621 | val = -0.198
#         (3 -2): pval = 0.01476 | val = -0.176
#         (1 -3): pval = 0.04597 | val = -0.145
#         (0 -1): pval = 0.04949 | val =  0.142
#
#     Variable 2 has 4 link(s):
#         (2 -1): pval = 0.00000 | val =  0.431
#         (1  0): pval = 0.00053 | val =  0.248 | unoriented link
#         (2 -2): pval = 0.00069 | val = -0.243
#         (3  0): pval = 0.00102 | val =  0.235 | unoriented link
#
#     Variable 3 has 5 link(s):
#         (4  0): pval = 0.00000 | val =  0.426 | unoriented link
#         (3 -1): pval = 0.00000 | val =  0.415
#         (2  0): pval = 0.00102 | val =  0.235 | unoriented link
#         (3 -2): pval = 0.01171 | val = -0.182
#         (0 -3): pval = 0.02074 | val = -0.167
#
#     Variable 4 has 4 link(s):
#         (3  0): pval = 0.00000 | val =  0.426 | unoriented link
#         (4 -1): pval = 0.00000 | val =  0.422
#         (4 -2): pval = 0.00000 | val = -0.365
#         (0  0): pval = 0.02531 | val =  0.162 | unoriented link
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 3
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable 0 has 1 link(s):
#         (0 -1): max_pval = 0.00000, |min_val| =  0.447
#
#     Variable 1 has 2 link(s):
#         (1 -1): max_pval = 0.00000, |min_val| =  0.450
#         (3 -2): max_pval = 0.01160, |min_val| =  0.181
#
#     Variable 2 has 1 link(s):
#         (2 -1): max_pval = 0.00000, |min_val| =  0.348
#
#     Variable 3 has 1 link(s):
#         (3 -1): max_pval = 0.00005, |min_val| =  0.287
#
#     Variable 4 has 2 link(s):
#         (4 -1): max_pval = 0.00000, |min_val| =  0.327
#         (4 -2): max_pval = 0.00125, |min_val| =  0.230
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 3
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable 0 has 4 link(s):
#         (0 -1): pval = 0.00000 | val =  0.549
#         (0 -2): pval = 0.00000 | val = -0.348
#         (1  0): pval = 0.00017 | val =  0.269 | unoriented link
#         (4  0): pval = 0.02531 | val =  0.162 | unoriented link
#
#     Variable 1 has 7 link(s):
#         (1 -1): pval = 0.00000 | val =  0.521
#         (0  0): pval = 0.00017 | val =  0.269 | unoriented link
#         (2  0): pval = 0.00053 | val =  0.248 | unoriented link
#         (1 -2): pval = 0.00621 | val = -0.198
#         (3 -2): pval = 0.01476 | val = -0.176
#         (1 -3): pval = 0.04597 | val = -0.145
#         (0 -1): pval = 0.04949 | val =  0.142
#
#     Variable 2 has 4 link(s):
#         (2 -1): pval = 0.00000 | val =  0.431
#         (1  0): pval = 0.00053 | val =  0.248 | unoriented link
#         (2 -2): pval = 0.00069 | val = -0.243
#         (3  0): pval = 0.00102 | val =  0.235 | unoriented link
#
#     Variable 3 has 5 link(s):
#         (4  0): pval = 0.00000 | val =  0.426 | unoriented link
#         (3 -1): pval = 0.00000 | val =  0.415
#         (2  0): pval = 0.00102 | val =  0.235 | unoriented link
#         (3 -2): pval = 0.01171 | val = -0.182
#         (0 -3): pval = 0.02074 | val = -0.167
#
#     Variable 4 has 4 link(s):
#         (3  0): pval = 0.00000 | val =  0.426 | unoriented link
#         (4 -1): pval = 0.00000 | val =  0.422
#         (4 -2): pval = 0.00000 | val = -0.365
#         (0  0): pval = 0.02531 | val =  0.162 | unoriented link
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 3
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable 0 has 1 link(s):
#         (0 -1): max_pval = 0.00000, |min_val| =  0.482
#
#     Variable 1 has 3 link(s):
#         (1 -1): max_pval = 0.00000, |min_val| =  0.416
#         (3 -2): max_pval = 0.00653, |min_val| =  0.211
#         (1 -3): max_pval = 0.02364, |min_val| =  0.176
#
#     Variable 2 has 1 link(s):
#         (2 -1): max_pval = 0.00000, |min_val| =  0.384
#
#     Variable 3 has 1 link(s):
#         (3 -1): max_pval = 0.00023, |min_val| =  0.284
#
#     Variable 4 has 2 link(s):
#         (4 -1): max_pval = 0.00008, |min_val| =  0.301
#         (4 -2): max_pval = 0.00674, |min_val| =  0.210
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 3
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable 0 has 6 link(s):
#         (0 -1): pval = 0.00000 | val =  0.579
#         (0 -2): pval = 0.00002 | val = -0.329
#         (1  0): pval = 0.00013 | val =  0.297 | unoriented link
#         (4  0): pval = 0.02235 | val =  0.179 | unoriented link
#         (1 -2): pval = 0.03370 | val = -0.167
#         (2 -1): pval = 0.04031 | val =  0.161
#
#     Variable 1 has 7 link(s):
#         (1 -1): pval = 0.00000 | val =  0.503
#         (0  0): pval = 0.00013 | val =  0.297 | unoriented link
#         (2  0): pval = 0.00037 | val =  0.277 | unoriented link
#         (1 -2): pval = 0.00160 | val = -0.248
#         (1 -3): pval = 0.00733 | val = -0.211
#         (3 -2): pval = 0.01208 | val = -0.197
#         (0 -1): pval = 0.04417 | val =  0.159
#
#     Variable 2 has 5 link(s):
#         (2 -1): pval = 0.00000 | val =  0.430
#         (1  0): pval = 0.00037 | val =  0.277 | unoriented link
#         (3  0): pval = 0.00230 | val =  0.237 | unoriented link
#         (2 -2): pval = 0.00593 | val = -0.215
#         (1 -2): pval = 0.04783 | val = -0.156
#
#     Variable 3 has 5 link(s):
#         (4  0): pval = 0.00000 | val =  0.414 | unoriented link
#         (3 -1): pval = 0.00000 | val =  0.379
#         (2  0): pval = 0.00230 | val =  0.237 | unoriented link
#         (0 -3): pval = 0.00989 | val = -0.202
#         (1 -3): pval = 0.01520 | val = -0.191
#
#     Variable 4 has 5 link(s):
#         (3  0): pval = 0.00000 | val =  0.414 | unoriented link
#         (4 -1): pval = 0.00000 | val =  0.389
#         (4 -2): pval = 0.00001 | val = -0.339
#         (0  0): pval = 0.02235 | val =  0.179 | unoriented link
#         (1 -2): pval = 0.02349 | val = -0.179
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 3
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable 0 has 1 link(s):
#         (0 -1): max_pval = 0.00000, |min_val| =  0.429
#
#     Variable 1 has 2 link(s):
#         (1 -1): max_pval = 0.00000, |min_val| =  0.453
#         (3 -2): max_pval = 0.01609, |min_val| =  0.188
#
#     Variable 2 has 1 link(s):
#         (2 -1): max_pval = 0.00000, |min_val| =  0.381
#
#     Variable 3 has 2 link(s):
#         (3 -1): max_pval = 0.00002, |min_val| =  0.330
#         (2 -2): max_pval = 0.04786, |min_val| =  0.154
#
#     Variable 4 has 2 link(s):
#         (4 -1): max_pval = 0.00010, |min_val| =  0.298
#         (4 -2): max_pval = 0.00407, |min_val| =  0.223
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 3
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable 0 has 3 link(s):
#         (0 -1): pval = 0.00000 | val =  0.543
#         (0 -2): pval = 0.00000 | val = -0.387
#         (1  0): pval = 0.00040 | val =  0.275 | unoriented link
#
#     Variable 1 has 5 link(s):
#         (1 -1): pval = 0.00000 | val =  0.518
#         (0  0): pval = 0.00040 | val =  0.275 | unoriented link
#         (2  0): pval = 0.00179 | val =  0.243 | unoriented link
#         (1 -2): pval = 0.01056 | val = -0.201
#         (3 -2): pval = 0.02899 | val = -0.172
#
#     Variable 2 has 4 link(s):
#         (2 -1): pval = 0.00000 | val =  0.460
#         (2 -2): pval = 0.00133 | val = -0.249
#         (1  0): pval = 0.00179 | val =  0.243 | unoriented link
#         (3  0): pval = 0.00388 | val =  0.226 | unoriented link
#
#     Variable 3 has 5 link(s):
#         (4  0): pval = 0.00000 | val =  0.471 | unoriented link
#         (3 -1): pval = 0.00000 | val =  0.442
#         (2  0): pval = 0.00388 | val =  0.226 | unoriented link
#         (3 -2): pval = 0.00915 | val = -0.205
#         (0 -3): pval = 0.02203 | val = -0.180
#
#     Variable 4 has 3 link(s):
#         (3  0): pval = 0.00000 | val =  0.471 | unoriented link
#         (4 -1): pval = 0.00000 | val =  0.375
#         (4 -2): pval = 0.00003 | val = -0.324
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 3
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable 0 has 3 link(s):
#         (0 -1): max_pval = 0.00000, |min_val| =  0.432
#         (2 -1): max_pval = 0.02804, |min_val| =  0.172
#         (2 -3): max_pval = 0.03584, |min_val| =  0.164
#
#     Variable 1 has 1 link(s):
#         (1 -1): max_pval = 0.00000, |min_val| =  0.484
#
#     Variable 2 has 1 link(s):
#         (2 -1): max_pval = 0.00001, |min_val| =  0.340
#
#     Variable 3 has 2 link(s):
#         (3 -1): max_pval = 0.00154, |min_val| =  0.245
#         (4 -3): max_pval = 0.02635, |min_val| =  0.174
#
#     Variable 4 has 2 link(s):
#         (4 -1): max_pval = 0.00006, |min_val| =  0.307
#         (4 -2): max_pval = 0.00102, |min_val| =  0.254
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 3
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable 0 has 5 link(s):
#         (0 -1): pval = 0.00000 | val =  0.521
#         (0 -2): pval = 0.00001 | val = -0.344
#         (1  0): pval = 0.00096 | val =  0.258 | unoriented link
#         (2 -3): pval = 0.01420 | val =  0.192
#         (2 -1): pval = 0.03212 | val =  0.168
#
#     Variable 1 has 5 link(s):
#         (1 -1): pval = 0.00000 | val =  0.564
#         (0  0): pval = 0.00096 | val =  0.258 | unoriented link
#         (1 -2): pval = 0.00115 | val = -0.252
#         (2  0): pval = 0.00460 | val =  0.221 | unoriented link
#         (1 -3): pval = 0.02010 | val = -0.182
#
#     Variable 2 has 4 link(s):
#         (2 -1): pval = 0.00000 | val =  0.401
#         (2 -2): pval = 0.00087 | val = -0.258
#         (1  0): pval = 0.00460 | val =  0.221 | unoriented link
#         (3  0): pval = 0.00660 | val =  0.213 | unoriented link
#
#     Variable 3 has 5 link(s):
#         (4  0): pval = 0.00000 | val =  0.471 | unoriented link
#         (3 -1): pval = 0.00000 | val =  0.359
#         (2  0): pval = 0.00660 | val =  0.213 | unoriented link
#         (4 -3): pval = 0.02983 | val = -0.171
#         (0 -3): pval = 0.04431 | val = -0.159
#
#     Variable 4 has 3 link(s):
#         (3  0): pval = 0.00000 | val =  0.471 | unoriented link
#         (4 -1): pval = 0.00000 | val =  0.405
#         (4 -2): pval = 0.00000 | val = -0.371
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 3
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable 0 has 1 link(s):
#         (0 -1): max_pval = 0.00000, |min_val| =  0.444
#
#     Variable 1 has 2 link(s):
#         (1 -1): max_pval = 0.00000, |min_val| =  0.429
#         (3 -2): max_pval = 0.03566, |min_val| =  0.164
#
#     Variable 2 has 1 link(s):
#         (2 -1): max_pval = 0.00000, |min_val| =  0.380
#
#     Variable 3 has 2 link(s):
#         (3 -1): max_pval = 0.00019, |min_val| =  0.288
#         (4 -3): max_pval = 0.03593, |min_val| =  0.164
#
#     Variable 4 has 2 link(s):
#         (4 -1): max_pval = 0.00001, |min_val| =  0.332
#         (4 -2): max_pval = 0.00136, |min_val| =  0.247
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 3
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable 0 has 4 link(s):
#         (0 -1): pval = 0.00000 | val =  0.544
#         (0 -2): pval = 0.00001 | val = -0.345
#         (1  0): pval = 0.00020 | val =  0.288 | unoriented link
#         (4  0): pval = 0.03180 | val =  0.169 | unoriented link
#
#     Variable 1 has 6 link(s):
#         (1 -1): pval = 0.00000 | val =  0.502
#         (0  0): pval = 0.00020 | val =  0.288 | unoriented link
#         (2  0): pval = 0.00254 | val =  0.236 | unoriented link
#         (0 -1): pval = 0.04112 | val =  0.161
#         (1 -2): pval = 0.04399 | val = -0.159
#         (3 -2): pval = 0.04395 | val = -0.159
#
#     Variable 2 has 4 link(s):
#         (2 -1): pval = 0.00000 | val =  0.443
#         (2 -2): pval = 0.00094 | val = -0.257
#         (1  0): pval = 0.00254 | val =  0.236 | unoriented link
#         (3  0): pval = 0.02683 | val =  0.174 | unoriented link
#
#     Variable 3 has 4 link(s):
#         (4  0): pval = 0.00000 | val =  0.429 | unoriented link
#         (3 -1): pval = 0.00000 | val =  0.360
#         (2  0): pval = 0.02683 | val =  0.174 | unoriented link
#         (0 -1): pval = 0.03240 | val =  0.168
#
#     Variable 4 has 4 link(s):
#         (4 -1): pval = 0.00000 | val =  0.431
#         (3  0): pval = 0.00000 | val =  0.429 | unoriented link
#         (4 -2): pval = 0.00000 | val = -0.393
#         (0  0): pval = 0.03180 | val =  0.169 | unoriented link
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 3
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable 0 has 1 link(s):
#         (0 -1): max_pval = 0.00000, |min_val| =  0.371
#
#     Variable 1 has 3 link(s):
#         (1 -1): max_pval = 0.00000, |min_val| =  0.456
#         (1 -3): max_pval = 0.02962, |min_val| =  0.169
#         (3 -2): max_pval = 0.02993, |min_val| =  0.169
#
#     Variable 2 has 1 link(s):
#         (2 -1): max_pval = 0.00005, |min_val| =  0.310
#
#     Variable 3 has 1 link(s):
#         (3 -1): max_pval = 0.00002, |min_val| =  0.329
#
#     Variable 4 has 2 link(s):
#         (4 -1): max_pval = 0.00001, |min_val| =  0.329
#         (4 -2): max_pval = 0.00234, |min_val| =  0.235
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 3
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable 0 has 4 link(s):
#         (0 -1): pval = 0.00000 | val =  0.472
#         (0 -2): pval = 0.00001 | val = -0.340
#         (1  0): pval = 0.00079 | val =  0.261 | unoriented link
#         (2 -3): pval = 0.03463 | val =  0.165
#
#     Variable 1 has 7 link(s):
#         (1 -1): pval = 0.00000 | val =  0.518
#         (2  0): pval = 0.00068 | val =  0.264 | unoriented link
#         (0  0): pval = 0.00079 | val =  0.261 | unoriented link
#         (1 -2): pval = 0.00199 | val = -0.242
#         (0 -2): pval = 0.02076 | val = -0.182
#         (1 -3): pval = 0.03244 | val = -0.169
#         (3 -2): pval = 0.03967 | val = -0.161
#
#     Variable 2 has 5 link(s):
#         (2 -1): pval = 0.00000 | val =  0.432
#         (1  0): pval = 0.00068 | val =  0.264 | unoriented link
#         (3  0): pval = 0.00069 | val =  0.262 | unoriented link
#         (2 -2): pval = 0.00106 | val = -0.253
#         (3 -1): pval = 0.00980 | val =  0.201
#
#     Variable 3 has 4 link(s):
#         (3 -1): pval = 0.00000 | val =  0.451
#         (4  0): pval = 0.00000 | val =  0.437 | unoriented link
#         (2  0): pval = 0.00069 | val =  0.262 | unoriented link
#         (3 -2): pval = 0.00865 | val = -0.204
#
#     Variable 4 has 4 link(s):
#         (3  0): pval = 0.00000 | val =  0.437 | unoriented link
#         (4 -1): pval = 0.00000 | val =  0.428
#         (4 -2): pval = 0.00000 | val = -0.374
#         (1 -2): pval = 0.03881 | val = -0.163
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 3
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable 0 has 1 link(s):
#         (0 -1): max_pval = 0.00000, |min_val| =  0.390
#
#     Variable 1 has 2 link(s):
#         (1 -1): max_pval = 0.00000, |min_val| =  0.471
#         (3 -2): max_pval = 0.00551, |min_val| =  0.215
#
#     Variable 2 has 1 link(s):
#         (2 -1): max_pval = 0.00001, |min_val| =  0.331
#
#     Variable 3 has 3 link(s):
#         (3 -1): max_pval = 0.00078, |min_val| =  0.259
#         (3 -3): max_pval = 0.01370, |min_val| =  0.192
#         (0 -3): max_pval = 0.01904, |min_val| =  0.182
#
#     Variable 4 has 3 link(s):
#         (4 -1): max_pval = 0.00000, |min_val| =  0.349
#         (3 -2): max_pval = 0.02522, |min_val| =  0.174
#         (4 -2): max_pval = 0.02997, |min_val| =  0.169
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 3
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable 0 has 4 link(s):
#         (0 -1): pval = 0.00000 | val =  0.518
#         (0 -2): pval = 0.00000 | val = -0.371
#         (1  0): pval = 0.00122 | val =  0.251 | unoriented link
#         (4  0): pval = 0.00996 | val =  0.202 | unoriented link
#
#     Variable 1 has 5 link(s):
#         (1 -1): pval = 0.00000 | val =  0.497
#         (2  0): pval = 0.00044 | val =  0.272 | unoriented link
#         (0  0): pval = 0.00122 | val =  0.251 | unoriented link
#         (3 -2): pval = 0.00875 | val = -0.205
#         (1 -2): pval = 0.04790 | val = -0.156
#
#     Variable 2 has 5 link(s):
#         (2 -1): pval = 0.00000 | val =  0.408
#         (1  0): pval = 0.00044 | val =  0.272 | unoriented link
#         (2 -2): pval = 0.00225 | val = -0.237
#         (3  0): pval = 0.00718 | val =  0.210 | unoriented link
#         (4 -3): pval = 0.02937 | val = -0.171
#
#     Variable 3 has 6 link(s):
#         (4  0): pval = 0.00000 | val =  0.442 | unoriented link
#         (3 -1): pval = 0.00000 | val =  0.369
#         (2  0): pval = 0.00718 | val =  0.210 | unoriented link
#         (0 -3): pval = 0.01623 | val = -0.188
#         (3 -2): pval = 0.02857 | val = -0.173
#         (4 -1): pval = 0.03542 | val =  0.166
#
#     Variable 4 has 4 link(s):
#         (4 -1): pval = 0.00000 | val =  0.445
#         (3  0): pval = 0.00000 | val =  0.442 | unoriented link
#         (4 -2): pval = 0.00026 | val = -0.284
#         (0  0): pval = 0.00996 | val =  0.202 | unoriented link
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 3
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable 0 has 2 link(s):
#         (0 -1): max_pval = 0.00000, |min_val| =  0.490
#         (2 -1): max_pval = 0.04975, |min_val| =  0.153
#
#     Variable 1 has 2 link(s):
#         (1 -1): max_pval = 0.00000, |min_val| =  0.453
#         (3 -2): max_pval = 0.02244, |min_val| =  0.178
#
#     Variable 2 has 1 link(s):
#         (2 -1): max_pval = 0.00000, |min_val| =  0.349
#
#     Variable 3 has 2 link(s):
#         (3 -1): max_pval = 0.00047, |min_val| =  0.269
#         (4 -3): max_pval = 0.02353, |min_val| =  0.176
#
#     Variable 4 has 2 link(s):
#         (4 -1): max_pval = 0.00000, |min_val| =  0.348
#         (4 -2): max_pval = 0.00395, |min_val| =  0.223
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 3
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable 0 has 5 link(s):
#         (0 -1): pval = 0.00000 | val =  0.567
#         (0 -2): pval = 0.00004 | val = -0.319
#         (1  0): pval = 0.00075 | val =  0.262 | unoriented link
#         (1 -2): pval = 0.02621 | val = -0.175
#         (0 -3): pval = 0.02677 | val = -0.174
#
#     Variable 1 has 6 link(s):
#         (1 -1): pval = 0.00000 | val =  0.531
#         (0  0): pval = 0.00075 | val =  0.262 | unoriented link
#         (2  0): pval = 0.00083 | val =  0.259 | unoriented link
#         (0 -1): pval = 0.01315 | val =  0.194
#         (3 -2): pval = 0.01705 | val = -0.187
#         (1 -2): pval = 0.04285 | val = -0.159
#
#     Variable 2 has 5 link(s):
#         (2 -1): pval = 0.00000 | val =  0.445
#         (1  0): pval = 0.00083 | val =  0.259 | unoriented link
#         (2 -2): pval = 0.00084 | val = -0.258
#         (3  0): pval = 0.00119 | val =  0.252 | unoriented link
#         (3 -1): pval = 0.01553 | val =  0.189
#
#     Variable 3 has 4 link(s):
#         (4  0): pval = 0.00000 | val =  0.382 | unoriented link
#         (3 -1): pval = 0.00000 | val =  0.363
#         (2  0): pval = 0.00119 | val =  0.252 | unoriented link
#         (3 -2): pval = 0.01135 | val = -0.198
#
#     Variable 4 has 3 link(s):
#         (4 -1): pval = 0.00000 | val =  0.450
#         (3  0): pval = 0.00000 | val =  0.382 | unoriented link
#         (4 -2): pval = 0.00000 | val = -0.367
#
#  Analysis started for target:  x0
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# Epoch:  1 [0%] 	Loss: 6.214725
# Epoch: 500 [50%] 	Loss: 3.209437
# Epoch: 1000 [100%] 	Loss: 3.197747
# Potential causes:  [0, 2]
# Validated causes:  [0]
#
#  Analysis started for target:  x1
# Epoch:  1 [0%] 	Loss: 5.367340
# Epoch: 500 [50%] 	Loss: 2.869753
# Epoch: 1000 [100%] 	Loss: 2.868983
# Potential causes:  [1]
# Validated causes:  [1]
#
#  Analysis started for target:  x2
# Epoch:  1 [0%] 	Loss: 5.143696
# Epoch: 500 [50%] 	Loss: 3.165811
# Epoch: 1000 [100%] 	Loss: 3.134760
# Potential causes:  [1, 3]
# Validated causes:  [1, 3]
#
#  Analysis started for target:  x3
# Epoch:  1 [0%] 	Loss: 4.818499
# Epoch: 500 [50%] 	Loss: 2.431975
# Epoch: 1000 [100%] 	Loss: 2.414724
# Potential causes:  [4, 3, 2]
# Validated causes:  [4, 3, 2]
#
#  Analysis started for target:  x4
# Epoch:  1 [0%] 	Loss: 5.899473
# Epoch: 500 [50%] 	Loss: 3.036919
# Epoch: 1000 [100%] 	Loss: 2.990702
# Potential causes:  [3]
# Validated causes:  [3]
# Processing dataset 2
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 3
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable 0 has 2 link(s):
#         (0 -1): max_pval = 0.00000, |min_val| =  0.336
#         (0 -2): max_pval = 0.03517, |min_val| =  0.151
#
#     Variable 1 has 3 link(s):
#         (1 -1): max_pval = 0.00000, |min_val| =  0.353
#         (0 -1): max_pval = 0.03309, |min_val| =  0.154
#         (6 -3): max_pval = 0.04229, |min_val| =  0.147
#
#     Variable 2 has 1 link(s):
#         (2 -1): max_pval = 0.00000, |min_val| =  0.384
#
#     Variable 3 has 2 link(s):
#         (3 -1): max_pval = 0.00000, |min_val| =  0.411
#         (3 -3): max_pval = 0.00798, |min_val| =  0.191
#
#     Variable 4 has 1 link(s):
#         (4 -1): max_pval = 0.00000, |min_val| =  0.439
#
#     Variable 5 has 2 link(s):
#         (5 -1): max_pval = 0.00001, |min_val| =  0.318
#         (5 -2): max_pval = 0.01276, |min_val| =  0.179
#
#     Variable 6 has 3 link(s):
#         (6 -1): max_pval = 0.00000, |min_val| =  0.382
#         (5 -1): max_pval = 0.00042, |min_val| =  0.252
#         (7 -1): max_pval = 0.01032, |min_val| =  0.185
#
#     Variable 7 has 3 link(s):
#         (7 -1): max_pval = 0.00042, |min_val| =  0.252
#         (7 -2): max_pval = 0.04105, |min_val| =  0.147
#         (5 -1): max_pval = 0.04497, |min_val| =  0.144
#
#     Variable 8 has 2 link(s):
#         (8 -1): max_pval = 0.00001, |min_val| =  0.310
#         (5 -1): max_pval = 0.02486, |min_val| =  0.161
#
#     Variable 9 has 3 link(s):
#         (5 -1): max_pval = 0.00035, |min_val| =  0.256
#         (9 -1): max_pval = 0.00056, |min_val| =  0.247
#         (7 -1): max_pval = 0.04716, |min_val| =  0.143
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 3
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable 0 has 9 link(s):
#         (0 -1): pval = 0.00000 | val =  0.467
#         (0 -2): pval = 0.00000 | val = -0.332
#         (1  0): pval = 0.00096 | val =  0.238 | unoriented link
#         (4  0): pval = 0.00159 | val =  0.227 | unoriented link
#         (2 -3): pval = 0.00587 | val =  0.199
#         (4 -1): pval = 0.03089 | val =  0.156
#         (7 -3): pval = 0.03865 | val = -0.151
#         (2 -2): pval = 0.03996 | val =  0.149
#         (5  0): pval = 0.04710 | val =  0.144 | unoriented link
#
#     Variable 1 has 8 link(s):
#         (1 -1): pval = 0.00000 | val =  0.443
#         (1 -2): pval = 0.00004 | val = -0.297
#         (2  0): pval = 0.00035 | val =  0.257 | unoriented link
#         (4  0): pval = 0.00085 | val =  0.240 | unoriented link
#         (0  0): pval = 0.00096 | val =  0.238 | unoriented link
#         (0 -1): pval = 0.00344 | val =  0.211
#         (0 -2): pval = 0.03046 | val = -0.157
#         (6 -3): pval = 0.03659 | val = -0.152
#
#     Variable 2 has 7 link(s):
#         (2 -1): pval = 0.00000 | val =  0.430
#         (7  0): pval = 0.00029 | val =  0.260 | unoriented link
#         (1  0): pval = 0.00035 | val =  0.257 | unoriented link
#         (3  0): pval = 0.00326 | val =  0.212 | unoriented link
#         (4  0): pval = 0.00798 | val =  0.191 | unoriented link
#         (1 -2): pval = 0.04582 | val = -0.145
#         (3 -3): pval = 0.04869 | val = -0.143
#
#     Variable 3 has 9 link(s):
#         (3 -1): pval = 0.00000 | val =  0.564
#         (4  0): pval = 0.00000 | val =  0.387 | unoriented link
#         (3 -2): pval = 0.00000 | val = -0.342
#         (3 -3): pval = 0.00117 | val = -0.233
#         (2  0): pval = 0.00326 | val =  0.212 | unoriented link
#         (2 -1): pval = 0.01610 | val =  0.174
#         (4 -1): pval = 0.01839 | val =  0.170
#         (7 -1): pval = 0.04120 | val =  0.149
#         (1 -3): pval = 0.04970 | val = -0.143
#
#     Variable 4 has 7 link(s):
#         (4 -1): pval = 0.00000 | val =  0.490
#         (3  0): pval = 0.00000 | val =  0.387 | unoriented link
#         (1  0): pval = 0.00085 | val =  0.240 | unoriented link
#         (0  0): pval = 0.00159 | val =  0.227 | unoriented link
#         (3 -2): pval = 0.00581 | val = -0.199
#         (4 -2): pval = 0.00608 | val = -0.197
#         (2  0): pval = 0.00798 | val =  0.191 | unoriented link
#
#     Variable 5 has 8 link(s):
#         (5 -1): pval = 0.00000 | val =  0.413
#         (5 -2): pval = 0.00002 | val = -0.304
#         (6  0): pval = 0.00011 | val =  0.277 | unoriented link
#         (9  0): pval = 0.00022 | val =  0.265 | unoriented link
#         (7  0): pval = 0.00131 | val =  0.231 | unoriented link
#         (8  0): pval = 0.02258 | val =  0.165 | unoriented link
#         (3 -2): pval = 0.02976 | val =  0.158
#         (0  0): pval = 0.04710 | val =  0.144 | unoriented link
#
#     Variable 6 has 7 link(s):
#         (6 -1): pval = 0.00000 | val =  0.363
#         (7  0): pval = 0.00001 | val =  0.311 | unoriented link
#         (5  0): pval = 0.00011 | val =  0.277 | unoriented link
#         (5 -1): pval = 0.00041 | val =  0.254
#         (8  0): pval = 0.01752 | val =  0.172 | unoriented link
#         (7 -1): pval = 0.01866 | val =  0.171
#         (9  0): pval = 0.01897 | val =  0.170 | unoriented link
#
#     Variable 7 has 8 link(s):
#         (8  0): pval = 0.00000 | val =  0.447 | unoriented link
#         (9  0): pval = 0.00000 | val =  0.330 | unoriented link
#         (7 -1): pval = 0.00001 | val =  0.323
#         (6  0): pval = 0.00001 | val =  0.311 | unoriented link
#         (7 -2): pval = 0.00009 | val = -0.281
#         (2  0): pval = 0.00029 | val =  0.260 | unoriented link
#         (5  0): pval = 0.00131 | val =  0.231 | unoriented link
#         (5 -1): pval = 0.00841 | val =  0.191
#
#     Variable 8 has 8 link(s):
#         (7  0): pval = 0.00000 | val =  0.447 | unoriented link
#         (8 -1): pval = 0.00000 | val =  0.438
#         (9  0): pval = 0.00000 | val =  0.435 | unoriented link
#         (8 -2): pval = 0.00006 | val = -0.286
#         (6  0): pval = 0.01752 | val =  0.172 | unoriented link
#         (7 -2): pval = 0.02038 | val = -0.169
#         (5  0): pval = 0.02258 | val =  0.165 | unoriented link
#         (0 -2): pval = 0.04575 | val =  0.145
#
#     Variable 9 has 9 link(s):
#         (8  0): pval = 0.00000 | val =  0.435 | unoriented link
#         (7  0): pval = 0.00000 | val =  0.330 | unoriented link
#         (9 -1): pval = 0.00001 | val =  0.313
#         (5  0): pval = 0.00022 | val =  0.265 | unoriented link
#         (5 -1): pval = 0.00061 | val =  0.246
#         (9 -2): pval = 0.00184 | val = -0.226
#         (8 -2): pval = 0.00255 | val = -0.218
#         (7 -1): pval = 0.01786 | val =  0.172
#         (6  0): pval = 0.01897 | val =  0.170 | unoriented link
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 3
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable 0 has 2 link(s):
#         (0 -1): max_pval = 0.00000, |min_val| =  0.336
#         (0 -2): max_pval = 0.03517, |min_val| =  0.151
#
#     Variable 1 has 3 link(s):
#         (1 -1): max_pval = 0.00000, |min_val| =  0.353
#         (0 -1): max_pval = 0.03309, |min_val| =  0.154
#         (6 -3): max_pval = 0.04229, |min_val| =  0.147
#
#     Variable 2 has 1 link(s):
#         (2 -1): max_pval = 0.00000, |min_val| =  0.384
#
#     Variable 3 has 2 link(s):
#         (3 -1): max_pval = 0.00000, |min_val| =  0.411
#         (3 -3): max_pval = 0.00798, |min_val| =  0.191
#
#     Variable 4 has 1 link(s):
#         (4 -1): max_pval = 0.00000, |min_val| =  0.439
#
#     Variable 5 has 2 link(s):
#         (5 -1): max_pval = 0.00001, |min_val| =  0.318
#         (5 -2): max_pval = 0.01276, |min_val| =  0.179
#
#     Variable 6 has 3 link(s):
#         (6 -1): max_pval = 0.00000, |min_val| =  0.382
#         (5 -1): max_pval = 0.00042, |min_val| =  0.252
#         (7 -1): max_pval = 0.01032, |min_val| =  0.185
#
#     Variable 7 has 3 link(s):
#         (7 -1): max_pval = 0.00042, |min_val| =  0.252
#         (7 -2): max_pval = 0.04105, |min_val| =  0.147
#         (5 -1): max_pval = 0.04497, |min_val| =  0.144
#
#     Variable 8 has 2 link(s):
#         (8 -1): max_pval = 0.00001, |min_val| =  0.310
#         (5 -1): max_pval = 0.02486, |min_val| =  0.161
#
#     Variable 9 has 3 link(s):
#         (5 -1): max_pval = 0.00035, |min_val| =  0.256
#         (9 -1): max_pval = 0.00056, |min_val| =  0.247
#         (7 -1): max_pval = 0.04716, |min_val| =  0.143
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 3
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable 0 has 9 link(s):
#         (0 -1): pval = 0.00000 | val =  0.467
#         (0 -2): pval = 0.00000 | val = -0.332
#         (1  0): pval = 0.00096 | val =  0.238 | unoriented link
#         (4  0): pval = 0.00159 | val =  0.227 | unoriented link
#         (2 -3): pval = 0.00587 | val =  0.199
#         (4 -1): pval = 0.03089 | val =  0.156
#         (7 -3): pval = 0.03865 | val = -0.151
#         (2 -2): pval = 0.03996 | val =  0.149
#         (5  0): pval = 0.04710 | val =  0.144 | unoriented link
#
#     Variable 1 has 8 link(s):
#         (1 -1): pval = 0.00000 | val =  0.443
#         (1 -2): pval = 0.00004 | val = -0.297
#         (2  0): pval = 0.00035 | val =  0.257 | unoriented link
#         (4  0): pval = 0.00085 | val =  0.240 | unoriented link
#         (0  0): pval = 0.00096 | val =  0.238 | unoriented link
#         (0 -1): pval = 0.00344 | val =  0.211
#         (0 -2): pval = 0.03046 | val = -0.157
#         (6 -3): pval = 0.03659 | val = -0.152
#
#     Variable 2 has 7 link(s):
#         (2 -1): pval = 0.00000 | val =  0.430
#         (7  0): pval = 0.00029 | val =  0.260 | unoriented link
#         (1  0): pval = 0.00035 | val =  0.257 | unoriented link
#         (3  0): pval = 0.00326 | val =  0.212 | unoriented link
#         (4  0): pval = 0.00798 | val =  0.191 | unoriented link
#         (1 -2): pval = 0.04582 | val = -0.145
#         (3 -3): pval = 0.04869 | val = -0.143
#
#     Variable 3 has 9 link(s):
#         (3 -1): pval = 0.00000 | val =  0.564
#         (4  0): pval = 0.00000 | val =  0.387 | unoriented link
#         (3 -2): pval = 0.00000 | val = -0.342
#         (3 -3): pval = 0.00117 | val = -0.233
#         (2  0): pval = 0.00326 | val =  0.212 | unoriented link
#         (2 -1): pval = 0.01610 | val =  0.174
#         (4 -1): pval = 0.01839 | val =  0.170
#         (7 -1): pval = 0.04120 | val =  0.149
#         (1 -3): pval = 0.04970 | val = -0.143
#
#     Variable 4 has 7 link(s):
#         (4 -1): pval = 0.00000 | val =  0.490
#         (3  0): pval = 0.00000 | val =  0.387 | unoriented link
#         (1  0): pval = 0.00085 | val =  0.240 | unoriented link
#         (0  0): pval = 0.00159 | val =  0.227 | unoriented link
#         (3 -2): pval = 0.00581 | val = -0.199
#         (4 -2): pval = 0.00608 | val = -0.197
#         (2  0): pval = 0.00798 | val =  0.191 | unoriented link
#
#     Variable 5 has 8 link(s):
#         (5 -1): pval = 0.00000 | val =  0.413
#         (5 -2): pval = 0.00002 | val = -0.304
#         (6  0): pval = 0.00011 | val =  0.277 | unoriented link
#         (9  0): pval = 0.00022 | val =  0.265 | unoriented link
#         (7  0): pval = 0.00131 | val =  0.231 | unoriented link
#         (8  0): pval = 0.02258 | val =  0.165 | unoriented link
#         (3 -2): pval = 0.02976 | val =  0.158
#         (0  0): pval = 0.04710 | val =  0.144 | unoriented link
#
#     Variable 6 has 7 link(s):
#         (6 -1): pval = 0.00000 | val =  0.363
#         (7  0): pval = 0.00001 | val =  0.311 | unoriented link
#         (5  0): pval = 0.00011 | val =  0.277 | unoriented link
#         (5 -1): pval = 0.00041 | val =  0.254
#         (8  0): pval = 0.01752 | val =  0.172 | unoriented link
#         (7 -1): pval = 0.01866 | val =  0.171
#         (9  0): pval = 0.01897 | val =  0.170 | unoriented link
#
#     Variable 7 has 8 link(s):
#         (8  0): pval = 0.00000 | val =  0.447 | unoriented link
#         (9  0): pval = 0.00000 | val =  0.330 | unoriented link
#         (7 -1): pval = 0.00001 | val =  0.323
#         (6  0): pval = 0.00001 | val =  0.311 | unoriented link
#         (7 -2): pval = 0.00009 | val = -0.281
#         (2  0): pval = 0.00029 | val =  0.260 | unoriented link
#         (5  0): pval = 0.00131 | val =  0.231 | unoriented link
#         (5 -1): pval = 0.00841 | val =  0.191
#
#     Variable 8 has 8 link(s):
#         (7  0): pval = 0.00000 | val =  0.447 | unoriented link
#         (8 -1): pval = 0.00000 | val =  0.438
#         (9  0): pval = 0.00000 | val =  0.435 | unoriented link
#         (8 -2): pval = 0.00006 | val = -0.286
#         (6  0): pval = 0.01752 | val =  0.172 | unoriented link
#         (7 -2): pval = 0.02038 | val = -0.169
#         (5  0): pval = 0.02258 | val =  0.165 | unoriented link
#         (0 -2): pval = 0.04575 | val =  0.145
#
#     Variable 9 has 9 link(s):
#         (8  0): pval = 0.00000 | val =  0.435 | unoriented link
#         (7  0): pval = 0.00000 | val =  0.330 | unoriented link
#         (9 -1): pval = 0.00001 | val =  0.313
#         (5  0): pval = 0.00022 | val =  0.265 | unoriented link
#         (5 -1): pval = 0.00061 | val =  0.246
#         (9 -2): pval = 0.00184 | val = -0.226
#         (8 -2): pval = 0.00255 | val = -0.218
#         (7 -1): pval = 0.01786 | val =  0.172
#         (6  0): pval = 0.01897 | val =  0.170 | unoriented link
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 3
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable 0 has 4 link(s):
#         (0 -1): max_pval = 0.00000, |min_val| =  0.381
#         (3 -2): max_pval = 0.00677, |min_val| =  0.210
#         (2 -3): max_pval = 0.01347, |min_val| =  0.193
#         (1 -2): max_pval = 0.03518, |min_val| =  0.164
#
#     Variable 1 has 2 link(s):
#         (1 -1): max_pval = 0.00012, |min_val| =  0.297
#         (0 -1): max_pval = 0.01960, |min_val| =  0.183
#
#     Variable 2 has 1 link(s):
#         (2 -1): max_pval = 0.00000, |min_val| =  0.407
#
#     Variable 3 has 4 link(s):
#         (3 -1): max_pval = 0.00000, |min_val| =  0.473
#         (3 -3): max_pval = 0.00100, |min_val| =  0.255
#         (2 -3): max_pval = 0.01277, |min_val| =  0.195
#         (7 -1): max_pval = 0.01965, |min_val| =  0.181
#
#     Variable 4 has 1 link(s):
#         (4 -1): max_pval = 0.00000, |min_val| =  0.437
#
#     Variable 5 has 2 link(s):
#         (5 -1): max_pval = 0.00002, |min_val| =  0.325
#         (5 -2): max_pval = 0.03520, |min_val| =  0.164
#
#     Variable 6 has 3 link(s):
#         (6 -1): max_pval = 0.00001, |min_val| =  0.348
#         (5 -1): max_pval = 0.00163, |min_val| =  0.245
#         (7 -1): max_pval = 0.00330, |min_val| =  0.229
#
#     Variable 7 has 2 link(s):
#         (7 -1): max_pval = 0.00103, |min_val| =  0.254
#         (0 -1): max_pval = 0.04915, |min_val| =  0.154
#
#     Variable 8 has 3 link(s):
#         (8 -1): max_pval = 0.00072, |min_val| =  0.261
#         (0 -1): max_pval = 0.01486, |min_val| =  0.191
#         (5 -1): max_pval = 0.01983, |min_val| =  0.182
#
#     Variable 9 has 3 link(s):
#         (5 -1): max_pval = 0.00024, |min_val| =  0.284
#         (9 -1): max_pval = 0.00310, |min_val| =  0.230
#         (7 -1): max_pval = 0.03589, |min_val| =  0.164
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 3
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable 0 has 8 link(s):
#         (0 -1): pval = 0.00000 | val =  0.410
#         (2 -3): pval = 0.00031 | val =  0.280
#         (3 -2): pval = 0.00145 | val = -0.251
#         (1 -2): pval = 0.00264 | val = -0.236
#         (0 -2): pval = 0.00859 | val = -0.209
#         (1  0): pval = 0.01327 | val =  0.195 | unoriented link
#         (4 -1): pval = 0.01727 | val =  0.188
#         (2 -2): pval = 0.02861 | val =  0.173
#
#     Variable 1 has 9 link(s):
#         (1 -1): pval = 0.00000 | val =  0.414
#         (1 -2): pval = 0.00002 | val = -0.332
#         (2  0): pval = 0.00017 | val =  0.291 | unoriented link
#         (4  0): pval = 0.00554 | val =  0.217 | unoriented link
#         (0  0): pval = 0.01327 | val =  0.195 | unoriented link
#         (1 -3): pval = 0.02391 | val = -0.178
#         (6 -3): pval = 0.03220 | val = -0.169
#         (0 -1): pval = 0.03240 | val =  0.169
#         (0 -2): pval = 0.03884 | val = -0.164
#
#     Variable 2 has 5 link(s):
#         (2 -1): pval = 0.00000 | val =  0.452
#         (1  0): pval = 0.00017 | val =  0.291 | unoriented link
#         (7  0): pval = 0.00220 | val =  0.239 | unoriented link
#         (1 -2): pval = 0.01018 | val = -0.201
#         (4  0): pval = 0.01705 | val =  0.187 | unoriented link
#
#     Variable 3 has 9 link(s):
#         (3 -1): pval = 0.00000 | val =  0.504
#         (4  0): pval = 0.00000 | val =  0.429 | unoriented link
#         (3 -2): pval = 0.00029 | val = -0.285
#         (7 -1): pval = 0.01409 | val =  0.194
#         (2 -3): pval = 0.01880 | val = -0.185
#         (5  0): pval = 0.02846 | val =  0.174 | unoriented link
#         (5 -2): pval = 0.03030 | val = -0.172
#         (3 -3): pval = 0.03150 | val = -0.171
#         (2 -2): pval = 0.04838 | val = -0.156
#
#     Variable 4 has 7 link(s):
#         (4 -1): pval = 0.00000 | val =  0.491
#         (3  0): pval = 0.00000 | val =  0.429 | unoriented link
#         (3 -2): pval = 0.00375 | val = -0.228
#         (1  0): pval = 0.00554 | val =  0.217 | unoriented link
#         (4 -2): pval = 0.00949 | val = -0.203
#         (0 -3): pval = 0.01394 | val = -0.194
#         (2  0): pval = 0.01705 | val =  0.187 | unoriented link
#
#     Variable 5 has 8 link(s):
#         (5 -1): pval = 0.00000 | val =  0.416
#         (5 -2): pval = 0.00013 | val = -0.295
#         (6  0): pval = 0.00150 | val =  0.248 | unoriented link
#         (9  0): pval = 0.00207 | val =  0.241 | unoriented link
#         (7  0): pval = 0.00493 | val =  0.221 | unoriented link
#         (3  0): pval = 0.02846 | val =  0.174 | unoriented link
#         (8  0): pval = 0.03288 | val =  0.168 | unoriented link
#         (3 -2): pval = 0.03614 | val =  0.166
#
#     Variable 6 has 8 link(s):
#         (7  0): pval = 0.00000 | val =  0.381 | unoriented link
#         (6 -1): pval = 0.00003 | val =  0.321
#         (5  0): pval = 0.00150 | val =  0.248 | unoriented link
#         (7 -1): pval = 0.00278 | val =  0.234
#         (5 -1): pval = 0.00278 | val =  0.234
#         (8  0): pval = 0.00814 | val =  0.209 | unoriented link
#         (9  0): pval = 0.00815 | val =  0.208 | unoriented link
#         (3 -3): pval = 0.03212 | val =  0.171
#
#     Variable 7 has 10 link(s):
#         (8  0): pval = 0.00000 | val =  0.520 | unoriented link
#         (6  0): pval = 0.00000 | val =  0.381 | unoriented link
#         (9  0): pval = 0.00000 | val =  0.351 | unoriented link
#         (7 -1): pval = 0.00001 | val =  0.337
#         (2  0): pval = 0.00220 | val =  0.239 | unoriented link
#         (7 -2): pval = 0.00357 | val = -0.228
#         (5  0): pval = 0.00493 | val =  0.221 | unoriented link
#         (8 -2): pval = 0.01513 | val = -0.192
#         (6 -2): pval = 0.02066 | val = -0.183
#         (0 -1): pval = 0.04217 | val =  0.161
#
#     Variable 8 has 8 link(s):
#         (7  0): pval = 0.00000 | val =  0.520 | unoriented link
#         (9  0): pval = 0.00000 | val =  0.415 | unoriented link
#         (8 -1): pval = 0.00000 | val =  0.392
#         (8 -2): pval = 0.00002 | val = -0.330
#         (6  0): pval = 0.00814 | val =  0.209 | unoriented link
#         (0 -1): pval = 0.01058 | val =  0.202
#         (5 -1): pval = 0.01952 | val =  0.184
#         (5  0): pval = 0.03288 | val =  0.168 | unoriented link
#
#     Variable 9 has 10 link(s):
#         (8  0): pval = 0.00000 | val =  0.415 | unoriented link
#         (7  0): pval = 0.00000 | val =  0.351 | unoriented link
#         (5 -1): pval = 0.00021 | val =  0.288
#         (9 -1): pval = 0.00031 | val =  0.282
#         (5  0): pval = 0.00207 | val =  0.241 | unoriented link
#         (8 -2): pval = 0.00281 | val = -0.235
#         (6  0): pval = 0.00815 | val =  0.208 | unoriented link
#         (9 -2): pval = 0.01129 | val = -0.200
#         (7 -1): pval = 0.03392 | val =  0.167
#         (6 -2): pval = 0.04847 | val = -0.157
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 3
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable 0 has 3 link(s):
#         (0 -1): max_pval = 0.00005, |min_val| =  0.313
#         (2 -3): max_pval = 0.00276, |min_val| =  0.232
#         (0 -2): max_pval = 0.01017, |min_val| =  0.200
#
#     Variable 1 has 1 link(s):
#         (1 -1): max_pval = 0.00000, |min_val| =  0.355
#
#     Variable 2 has 1 link(s):
#         (2 -1): max_pval = 0.00000, |min_val| =  0.369
#
#     Variable 3 has 2 link(s):
#         (3 -1): max_pval = 0.00000, |min_val| =  0.428
#         (3 -3): max_pval = 0.00149, |min_val| =  0.247
#
#     Variable 4 has 1 link(s):
#         (4 -1): max_pval = 0.00000, |min_val| =  0.429
#
#     Variable 5 has 2 link(s):
#         (5 -1): max_pval = 0.00002, |min_val| =  0.323
#         (5 -2): max_pval = 0.01811, |min_val| =  0.184
#
#     Variable 6 has 3 link(s):
#         (6 -1): max_pval = 0.00000, |min_val| =  0.373
#         (5 -1): max_pval = 0.00426, |min_val| =  0.223
#         (7 -1): max_pval = 0.01427, |min_val| =  0.192
#
#     Variable 7 has 1 link(s):
#         (7 -1): max_pval = 0.00031, |min_val| =  0.278
#
#     Variable 8 has 2 link(s):
#         (8 -1): max_pval = 0.00046, |min_val| =  0.271
#         (5 -1): max_pval = 0.04905, |min_val| =  0.154
#
#     Variable 9 has 3 link(s):
#         (7 -1): max_pval = 0.00336, |min_val| =  0.228
#         (5 -1): max_pval = 0.00474, |min_val| =  0.222
#         (9 -1): max_pval = 0.04248, |min_val| =  0.160
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 3
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable 0 has 8 link(s):
#         (0 -1): pval = 0.00000 | val =  0.414
#         (0 -2): pval = 0.00001 | val = -0.342
#         (1  0): pval = 0.00159 | val =  0.247 | unoriented link
#         (4  0): pval = 0.00378 | val =  0.227 | unoriented link
#         (2 -3): pval = 0.00462 | val =  0.221
#         (3 -2): pval = 0.02153 | val = -0.182
#         (7 -3): pval = 0.03499 | val = -0.166
#         (1 -2): pval = 0.04567 | val = -0.158
#
#     Variable 1 has 7 link(s):
#         (1 -1): pval = 0.00000 | val =  0.463
#         (2  0): pval = 0.00094 | val =  0.257 | unoriented link
#         (0  0): pval = 0.00159 | val =  0.247 | unoriented link
#         (1 -2): pval = 0.00165 | val = -0.245
#         (4  0): pval = 0.00473 | val =  0.220 | unoriented link
#         (0 -1): pval = 0.01449 | val =  0.192
#         (6 -3): pval = 0.04547 | val = -0.158
#
#     Variable 2 has 6 link(s):
#         (2 -1): pval = 0.00000 | val =  0.403
#         (1  0): pval = 0.00094 | val =  0.257 | unoriented link
#         (7  0): pval = 0.00107 | val =  0.254 | unoriented link
#         (3  0): pval = 0.00272 | val =  0.234 | unoriented link
#         (4  0): pval = 0.01191 | val =  0.197 | unoriented link
#         (5 -2): pval = 0.04348 | val = -0.159
#
#     Variable 3 has 10 link(s):
#         (3 -1): pval = 0.00000 | val =  0.574
#         (4  0): pval = 0.00000 | val =  0.428 | unoriented link
#         (3 -2): pval = 0.00000 | val = -0.352
#         (3 -3): pval = 0.00034 | val = -0.278
#         (2  0): pval = 0.00272 | val =  0.234 | unoriented link
#         (2 -2): pval = 0.00750 | val = -0.209
#         (2 -1): pval = 0.01241 | val =  0.196
#         (2 -3): pval = 0.02756 | val = -0.173
#         (1 -3): pval = 0.03912 | val = -0.162
#         (7 -1): pval = 0.04066 | val =  0.161
#
#     Variable 4 has 7 link(s):
#         (4 -1): pval = 0.00000 | val =  0.492
#         (3  0): pval = 0.00000 | val =  0.428 | unoriented link
#         (3 -2): pval = 0.00170 | val = -0.245
#         (0  0): pval = 0.00378 | val =  0.227 | unoriented link
#         (1  0): pval = 0.00473 | val =  0.220 | unoriented link
#         (4 -2): pval = 0.01027 | val = -0.201
#         (2  0): pval = 0.01191 | val =  0.197 | unoriented link
#
#     Variable 5 has 7 link(s):
#         (5 -1): pval = 0.00000 | val =  0.425
#         (5 -2): pval = 0.00006 | val = -0.311
#         (9  0): pval = 0.00012 | val =  0.299 | unoriented link
#         (6  0): pval = 0.00042 | val =  0.275 | unoriented link
#         (7  0): pval = 0.00155 | val =  0.247 | unoriented link
#         (8  0): pval = 0.02018 | val =  0.182 | unoriented link
#         (3 -2): pval = 0.03278 | val =  0.168
#
#     Variable 6 has 7 link(s):
#         (6 -1): pval = 0.00000 | val =  0.357
#         (7  0): pval = 0.00003 | val =  0.321 | unoriented link
#         (5  0): pval = 0.00042 | val =  0.275 | unoriented link
#         (8  0): pval = 0.00291 | val =  0.233 | unoriented link
#         (5 -1): pval = 0.00503 | val =  0.220
#         (9  0): pval = 0.00612 | val =  0.215 | unoriented link
#         (7 -1): pval = 0.00739 | val =  0.210
#
#     Variable 7 has 8 link(s):
#         (8  0): pval = 0.00000 | val =  0.481 | unoriented link
#         (7 -1): pval = 0.00000 | val =  0.397
#         (9  0): pval = 0.00000 | val =  0.350 | unoriented link
#         (6  0): pval = 0.00003 | val =  0.321 | unoriented link
#         (7 -2): pval = 0.00025 | val = -0.283
#         (2  0): pval = 0.00107 | val =  0.254 | unoriented link
# ...
#         (3  0): pval = 0.00000 | val =  0.594 | unoriented link
#         (2 -2): pval = 0.00000 | val = -0.580
#         (3 -2): pval = 0.00029 | val = -0.402
#         (4  0): pval = 0.00033 | val =  0.401 | unoriented link
#         (2 -3): pval = 0.02414 | val = -0.257
#         (4 -2): pval = 0.04761 | val = -0.228
#
#     Variable 3 has 7 link(s):
#         (3 -1): pval = 0.00000 | val =  0.660
#         (2  0): pval = 0.00000 | val =  0.594 | unoriented link
#         (4  0): pval = 0.00001 | val =  0.494 | unoriented link
#         (3 -2): pval = 0.00017 | val = -0.416
#         (2 -2): pval = 0.00552 | val = -0.313
#         (4 -2): pval = 0.01656 | val = -0.274
#         (2 -3): pval = 0.02996 | val = -0.248
#
#     Variable 4 has 5 link(s):
#         (4 -2): pval = 0.00000 | val = -0.500
#         (3  0): pval = 0.00001 | val =  0.494 | unoriented link
#         (4 -1): pval = 0.00001 | val =  0.491
#         (2  0): pval = 0.00033 | val =  0.401 | unoriented link
#         (4 -3): pval = 0.02629 | val =  0.257
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 3
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable 0 has 2 link(s):
#         (0 -2): max_pval = 0.00010, |min_val| =  0.420
#         (0 -1): max_pval = 0.00249, |min_val| =  0.334
#
#     Variable 1 has 2 link(s):
#         (1 -1): max_pval = 0.00000, |min_val| =  0.652
#         (1 -2): max_pval = 0.03275, |min_val| =  0.239
#
#     Variable 2 has 2 link(s):
#         (2 -1): max_pval = 0.00002, |min_val| =  0.463
#         (3 -3): max_pval = 0.03311, |min_val| =  0.240
#
#     Variable 3 has 2 link(s):
#         (3 -1): max_pval = 0.00004, |min_val| =  0.445
#         (2 -3): max_pval = 0.00906, |min_val| =  0.292
#
#     Variable 4 has 2 link(s):
#         (4 -1): max_pval = 0.01469, |min_val| =  0.274
#         (4 -2): max_pval = 0.04555, |min_val| =  0.224
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 3
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable 0 has 5 link(s):
#         (0 -1): pval = 0.00000 | val =  0.574
#         (0 -2): pval = 0.00000 | val = -0.537
#         (1  0): pval = 0.00026 | val =  0.407 | unoriented link
#         (4  0): pval = 0.01057 | val =  0.292 | unoriented link
#         (0 -3): pval = 0.04825 | val =  0.227
#
#     Variable 1 has 8 link(s):
#         (1 -1): pval = 0.00000 | val =  0.679
#         (1 -2): pval = 0.00006 | val = -0.441
#         (0  0): pval = 0.00026 | val =  0.407 | unoriented link
#         (1 -3): pval = 0.00542 | val =  0.316
#         (4  0): pval = 0.00978 | val =  0.295 | unoriented link
#         (0 -3): pval = 0.01962 | val =  0.267
#         (2  0): pval = 0.04194 | val =  0.234 | unoriented link
#         (3  0): pval = 0.04247 | val =  0.233 | unoriented link
#
#     Variable 2 has 8 link(s):
#         (2 -1): pval = 0.00000 | val =  0.702
#         (3  0): pval = 0.00000 | val =  0.668 | unoriented link
#         (2 -2): pval = 0.00000 | val = -0.529
#         (2 -3): pval = 0.00050 | val = -0.390
#         (4  0): pval = 0.00071 | val =  0.380 | unoriented link
#         (4 -2): pval = 0.01666 | val = -0.274
#         (3 -2): pval = 0.01859 | val = -0.268
#         (1  0): pval = 0.04194 | val =  0.234 | unoriented link
#
#     Variable 3 has 9 link(s):
#         (2  0): pval = 0.00000 | val =  0.668 | unoriented link
#         (3 -1): pval = 0.00000 | val =  0.616
#         (4  0): pval = 0.00000 | val =  0.575 | unoriented link
#         (3 -2): pval = 0.00020 | val = -0.415
#         (2 -3): pval = 0.00106 | val = -0.366
#         (2 -2): pval = 0.00206 | val = -0.346
#         (0 -3): pval = 0.01790 | val =  0.271
#         (2 -1): pval = 0.03489 | val =  0.242
#         (1  0): pval = 0.04247 | val =  0.233 | unoriented link
#
#     Variable 4 has 7 link(s):
#         (3  0): pval = 0.00000 | val =  0.575 | unoriented link
#         (4 -1): pval = 0.00000 | val =  0.503
#         (4 -2): pval = 0.00014 | val = -0.421
#         (2  0): pval = 0.00071 | val =  0.380 | unoriented link
#         (1  0): pval = 0.00978 | val =  0.295 | unoriented link
#         (0  0): pval = 0.01057 | val =  0.292 | unoriented link
#         (4 -3): pval = 0.04404 | val =  0.232
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 3
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable 0 has 3 link(s):
#         (0 -2): max_pval = 0.00003, |min_val| =  0.448
#         (0 -1): max_pval = 0.00152, |min_val| =  0.349
#         (1 -3): max_pval = 0.02290, |min_val| =  0.257
#
#     Variable 1 has 4 link(s):
#         (1 -1): max_pval = 0.00000, |min_val| =  0.655
#         (0 -3): max_pval = 0.02708, |min_val| =  0.250
#         (2 -3): max_pval = 0.03895, |min_val| =  0.234
#         (1 -2): max_pval = 0.04318, |min_val| =  0.227
#
#     Variable 2 has 2 link(s):
#         (2 -1): max_pval = 0.00000, |min_val| =  0.524
#         (3 -3): max_pval = 0.00414, |min_val| =  0.319
#
#     Variable 3 has 1 link(s):
#         (3 -1): max_pval = 0.00000, |min_val| =  0.513
#
#     Variable 4 has 2 link(s):
#         (2 -1): max_pval = 0.00360, |min_val| =  0.324
#         (4 -2): max_pval = 0.00792, |min_val| =  0.295
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 3
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable 0 has 3 link(s):
#         (0 -2): pval = 0.00000 | val = -0.576
#         (0 -1): pval = 0.00000 | val =  0.560
#         (1  0): pval = 0.00313 | val =  0.341 | unoriented link
#
#     Variable 1 has 6 link(s):
#         (1 -1): pval = 0.00000 | val =  0.684
#         (1 -2): pval = 0.00000 | val = -0.527
#         (0 -3): pval = 0.00221 | val =  0.350
#         (0  0): pval = 0.00313 | val =  0.341 | unoriented link
#         (2  0): pval = 0.00831 | val =  0.305 | unoriented link
#         (1 -3): pval = 0.02818 | val =  0.259
#
#     Variable 2 has 7 link(s):
#         (2 -1): pval = 0.00000 | val =  0.686
#         (3  0): pval = 0.00000 | val =  0.661 | unoriented link
#         (2 -2): pval = 0.00003 | val = -0.459
#         (3 -2): pval = 0.00276 | val = -0.335
#         (1  0): pval = 0.00831 | val =  0.305 | unoriented link
#         (4  0): pval = 0.01974 | val =  0.265 | unoriented link
#         (3 -3): pval = 0.04870 | val =  0.224
#
#     Variable 3 has 8 link(s):
#         (3 -1): pval = 0.00000 | val =  0.676
#         (2  0): pval = 0.00000 | val =  0.661 | unoriented link
#         (4  0): pval = 0.00005 | val =  0.445 | unoriented link
#         (3 -2): pval = 0.00021 | val = -0.408
#         (2 -1): pval = 0.00684 | val =  0.306
#         (2 -2): pval = 0.01065 | val = -0.290
#         (0 -3): pval = 0.02357 | val =  0.260
#         (2 -3): pval = 0.03629 | val = -0.239
#
#     Variable 4 has 5 link(s):
#         (3  0): pval = 0.00005 | val =  0.445 | unoriented link
#         (2 -1): pval = 0.00113 | val =  0.364
#         (4 -2): pval = 0.00130 | val = -0.360
#         (4 -1): pval = 0.00418 | val =  0.325
#         (2  0): pval = 0.01974 | val =  0.265 | unoriented link
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 3
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable 0 has 2 link(s):
#         (0 -1): max_pval = 0.00020, |min_val| =  0.404
#         (0 -2): max_pval = 0.00269, |min_val| =  0.331
#
#     Variable 1 has 2 link(s):
#         (1 -1): max_pval = 0.00000, |min_val| =  0.634
#         (0 -3): max_pval = 0.04443, |min_val| =  0.225
#
#     Variable 2 has 2 link(s):
#         (2 -1): max_pval = 0.00003, |min_val| =  0.449
#         (3 -3): max_pval = 0.00223, |min_val| =  0.339
#
#     Variable 3 has 1 link(s):
#         (3 -1): max_pval = 0.00000, |min_val| =  0.492
#
#     Variable 4 has 2 link(s):
#         (2 -1): max_pval = 0.00093, |min_val| =  0.363
#         (4 -2): max_pval = 0.00583, |min_val| =  0.306
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 3
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable 0 has 4 link(s):
#         (0 -1): pval = 0.00000 | val =  0.645
#         (0 -2): pval = 0.00000 | val = -0.561
#         (1  0): pval = 0.00565 | val =  0.315 | unoriented link
#         (4  0): pval = 0.03608 | val =  0.241 | unoriented link
#
#     Variable 1 has 3 link(s):
#         (1 -1): pval = 0.00000 | val =  0.672
#         (1 -2): pval = 0.00034 | val = -0.401
#         (0  0): pval = 0.00565 | val =  0.315 | unoriented link
#
#     Variable 2 has 7 link(s):
#         (3  0): pval = 0.00000 | val =  0.648 | unoriented link
#         (2 -1): pval = 0.00000 | val =  0.587
#         (2 -2): pval = 0.00018 | val = -0.416
#         (4  0): pval = 0.01155 | val =  0.286 | unoriented link
#         (3 -2): pval = 0.01362 | val = -0.278
#         (3 -3): pval = 0.02249 | val =  0.258
#         (4 -2): pval = 0.03489 | val = -0.242
#
#     Variable 3 has 7 link(s):
#         (2  0): pval = 0.00000 | val =  0.648 | unoriented link
#         (3 -1): pval = 0.00000 | val =  0.607
#         (4  0): pval = 0.00001 | val =  0.475 | unoriented link
#         (3 -2): pval = 0.00071 | val = -0.375
#         (4 -2): pval = 0.01537 | val = -0.275
#         (2 -2): pval = 0.02784 | val = -0.251
#         (0 -3): pval = 0.04053 | val =  0.234
#
#     Variable 4 has 7 link(s):
#         (3  0): pval = 0.00001 | val =  0.475 | unoriented link
#         (4 -2): pval = 0.00027 | val = -0.404
#         (4 -1): pval = 0.00172 | val =  0.354
#         (2 -3): pval = 0.00873 | val =  0.299
#         (2  0): pval = 0.01155 | val =  0.286 | unoriented link
#         (0  0): pval = 0.03608 | val =  0.241 | unoriented link
#         (2 -1): pval = 0.03776 | val =  0.237
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 3
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable 0 has 2 link(s):
#         (0 -1): max_pval = 0.00024, |min_val| =  0.400
#         (0 -2): max_pval = 0.01018, |min_val| =  0.286
#
#     Variable 1 has 2 link(s):
#         (1 -1): max_pval = 0.00000, |min_val| =  0.654
#         (0 -3): max_pval = 0.03743, |min_val| =  0.235
#
#     Variable 2 has 2 link(s):
#         (2 -1): max_pval = 0.00033, |min_val| =  0.394
#         (3 -3): max_pval = 0.02813, |min_val| =  0.247
#
#     Variable 3 has 1 link(s):
#         (3 -1): max_pval = 0.00000, |min_val| =  0.553
#
#     Variable 4 has 2 link(s):
#         (4 -2): max_pval = 0.00086, |min_val| =  0.366
#         (4 -1): max_pval = 0.00469, |min_val| =  0.313
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 3
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable 0 has 3 link(s):
#         (0 -1): pval = 0.00000 | val =  0.597
#         (0 -2): pval = 0.00000 | val = -0.514
#         (1  0): pval = 0.00011 | val =  0.430 | unoriented link
#
#     Variable 1 has 4 link(s):
#         (1 -1): pval = 0.00000 | val =  0.700
#         (0  0): pval = 0.00011 | val =  0.430 | unoriented link
#         (1 -2): pval = 0.00221 | val = -0.346
#         (2 -2): pval = 0.02963 | val = -0.250
#
#     Variable 2 has 6 link(s):
#         (2 -1): pval = 0.00000 | val =  0.643
#         (3  0): pval = 0.00000 | val =  0.610 | unoriented link
#         (2 -2): pval = 0.00001 | val = -0.497
#         (4  0): pval = 0.00040 | val =  0.396 | unoriented link
#         (2 -3): pval = 0.00895 | val = -0.298
#         (3 -2): pval = 0.03649 | val = -0.237
#
#     Variable 3 has 6 link(s):
#         (3 -1): pval = 0.00000 | val =  0.644
#         (2  0): pval = 0.00000 | val =  0.610 | unoriented link
#         (4  0): pval = 0.00002 | val =  0.464 | unoriented link
#         (3 -2): pval = 0.00126 | val = -0.359
#         (0 -3): pval = 0.00404 | val =  0.324
#         (2 -2): pval = 0.00473 | val = -0.319
#
#     Variable 4 has 7 link(s):
#         (4 -2): pval = 0.00000 | val = -0.545
#         (4 -1): pval = 0.00000 | val =  0.507
#         (3  0): pval = 0.00002 | val =  0.464 | unoriented link
#         (2  0): pval = 0.00040 | val =  0.396 | unoriented link
#         (4 -3): pval = 0.02248 | val =  0.262
#         (2 -1): pval = 0.04150 | val =  0.234
#         (3 -1): pval = 0.04983 | val =  0.224
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 3
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable 0 has 2 link(s):
#         (0 -1): max_pval = 0.00031, |min_val| =  0.393
#         (0 -2): max_pval = 0.00713, |min_val| =  0.299
#
#     Variable 1 has 2 link(s):
#         (1 -1): max_pval = 0.00000, |min_val| =  0.749
#         (1 -2): max_pval = 0.00146, |min_val| =  0.350
#
#     Variable 2 has 2 link(s):
#         (2 -1): max_pval = 0.00004, |min_val| =  0.446
#         (3 -3): max_pval = 0.02059, |min_val| =  0.260
#
#     Variable 3 has 1 link(s):
#         (3 -1): max_pval = 0.00000, |min_val| =  0.497
#
#     Variable 4 has 2 link(s):
#         (2 -1): max_pval = 0.00768, |min_val| =  0.298
#         (4 -2): max_pval = 0.01068, |min_val| =  0.288
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 3
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable 0 has 3 link(s):
#         (0 -1): pval = 0.00000 | val =  0.630
#         (0 -2): pval = 0.00000 | val = -0.523
#         (1  0): pval = 0.00946 | val =  0.296 | unoriented link
#
#     Variable 1 has 4 link(s):
#         (1 -1): pval = 0.00000 | val =  0.743
#         (1 -2): pval = 0.00010 | val = -0.430
#         (0  0): pval = 0.00946 | val =  0.296 | unoriented link
#         (1 -3): pval = 0.01713 | val =  0.273
#
#     Variable 2 has 7 link(s):
#         (2 -1): pval = 0.00000 | val =  0.672
#         (3  0): pval = 0.00000 | val =  0.655 | unoriented link
#         (2 -2): pval = 0.00000 | val = -0.513
#         (3 -2): pval = 0.00369 | val = -0.325
#         (4  0): pval = 0.01072 | val =  0.289 | unoriented link
#         (2 -3): pval = 0.03121 | val = -0.247
#         (4 -2): pval = 0.03684 | val = -0.240
#
#     Variable 3 has 8 link(s):
#         (3 -1): pval = 0.00000 | val =  0.672
#         (2  0): pval = 0.00000 | val =  0.655 | unoriented link
#         (4  0): pval = 0.00004 | val =  0.452 | unoriented link
#         (3 -2): pval = 0.00029 | val = -0.400
#         (2 -2): pval = 0.01071 | val = -0.289
#         (4 -2): pval = 0.02300 | val = -0.259
#         (0 -3): pval = 0.02836 | val =  0.250
#         (2 -3): pval = 0.03514 | val = -0.240
#
#     Variable 4 has 6 link(s):
#         (3  0): pval = 0.00004 | val =  0.452 | unoriented link
#         (4 -2): pval = 0.00019 | val = -0.413
#         (4 -1): pval = 0.00050 | val =  0.390
#         (2 -1): pval = 0.00064 | val =  0.380
#         (2  0): pval = 0.01072 | val =  0.289 | unoriented link
#         (1 -3): pval = 0.02560 | val =  0.256
#
#  Analysis started for target:  x0
# Epoch:  1 [0%] 	Loss: 5.157439
# Epoch: 500 [50%] 	Loss: 1.494770
# Epoch: 1000 [100%] 	Loss: 1.477326
# Potential causes:  [0, 4]
# Validated causes:  [0, 4]
#
#  Analysis started for target:  x1
# Epoch:  1 [0%] 	Loss: 4.549680
# Epoch: 500 [50%] 	Loss: 1.127424
# Epoch: 1000 [100%] 	Loss: 1.104833
# Potential causes:  [1]
# Validated causes:  [1]
#
#  Analysis started for target:  x2
# Epoch:  1 [0%] 	Loss: 5.938888
# Epoch: 500 [50%] 	Loss: 1.342625
# Epoch: 1000 [100%] 	Loss: 1.332831
# Potential causes:  [3, 2]
# Validated causes:  [3, 2]
#
#  Analysis started for target:  x3
# Epoch:  1 [0%] 	Loss: 4.355319
# Epoch: 500 [50%] 	Loss: 0.958125
# Epoch: 1000 [100%] 	Loss: 0.920007
# Potential causes:  [3, 2]
# Validated causes:  [3, 2]
#
#  Analysis started for target:  x4
# Epoch:  1 [0%] 	Loss: 4.891413
# Epoch: 500 [50%] 	Loss: 1.578825
# Epoch: 1000 [100%] 	Loss: 1.542224
# Potential causes:  [3, 1]
# Validated causes:  [3, 1]
